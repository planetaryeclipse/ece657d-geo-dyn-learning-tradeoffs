# %%
from pathlib import Path

from src.episodes.history import IntrinsicHistory, History

# %%
history = History.load(Path("../data/unforced_dynamics/dim_1/radius_1.0/ic_0.npz"))

# %%
print(history.intrinsic.keys())
print(history.intrinsic["U0"].valid)
# Out:
# dict_keys([np.str_('U0'), np.str_('U1')])
# [[0.59072596]
#  [0.59795627]
#  [0.60518659]
#  ...
#  [0.75458837]
#  [0.74735806]
#  [0.74012775]]
